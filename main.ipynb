# %%
from typing import TypedDict

# %%
class State(TypedDict):
    messages:str

# %%
def chat(state:State) ->State:
      return {"messages": "I am llama"}

# %%
from dotenv import load_dotenv
import os
load_dotenv(override=True)
GROQ_API_KEY = os.getenv("GROQ_API_KEY")

# %%
from langchain_groq import ChatGroq
def chat(state:State) ->State:
    model = ChatGroq(
        model = "llama-3.3-70b-versatile",
        api_key=GROQ_API_KEY
    )
    return{"messages":model.invoke([state["messages"]]).content}
# Out:
# e:\Traning\enviroment_name\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
from langgraph.graph import START ,END,StateGraph

# %%
graph_builder = StateGraph(State)

# %%
graph_builder.add_node("chat_node" ,chat)
graph_builder.add_edge(START,"chat_node")
graph_builder.add_edge("chat_node",END)
graph = graph_builder.compile()

# %%
graph.invoke({"messages" :"do you know about api"})
# Out:
# {'messages': "API stands for Application Programming Interface. It's a set of defined rules that enables different software systems to communicate with each other. APIs allow for the exchange of data between applications, services, or systems, making it a crucial component of modern software development.\n\nHere are some key aspects of APIs:\n\n1. **Structure**: An API defines a set of endpoints, which are URLs that accept specific types of requests (e.g., GET, POST, PUT, DELETE). Each endpoint typically has a specific response format (e.g., JSON, XML).\n2. **Request and Response**: When a client (e.g., a web application) sends a request to an API, the API processes the request and returns a response. The response may contain data, status codes, or error messages.\n3. **Security**: APIs often require authentication and authorization to ensure that only authorized clients can access the data or functionality. This is typically done using mechanisms like API keys, OAuth, or JWT (JSON Web Tokens).\n4. **Data Formats**: APIs can return data in various formats, such as JSON, XML, CSV, or even images.\n\nTypes of APIs:\n\n1. **Web APIs**: These are APIs that are accessed over the web, typically using HTTP requests.\n2. **Mobile APIs**: These are APIs designed specifically for mobile applications, often using protocols like REST or gRPC.\n3. **Microservices APIs**: These are APIs that enable communication between microservices within a larger application or system.\n4. **Database APIs**: These are APIs that provide access to a database, allowing clients to perform CRUD (Create, Read, Update, Delete) operations.\n\nAPI Design Principles:\n\n1. **RESTful**: APIs that follow the REST (Representational State of Resource) architecture are often considered best practice.\n2. **Consistent**: APIs should have a consistent naming convention and follow a predictable structure.\n3. **Secure**: APIs should be secure, with proper authentication and authorization mechanisms in place.\n4. **Documented**: APIs should have clear and up-to-date documentation, including code snippets and examples.\n\nSome popular API frameworks and libraries:\n\n1. **Express.js** (Node.js): A popular framework for building web APIs.\n2. **Django REST framework** (Python): A high-level framework for building web APIs.\n3. **Spring Boot** (Java): A popular framework for building web APIs.\n4. **gRPC** (C++, Java, Python): A high-performance RPC framework.\n\nAPI Use Cases:\n\n1. **Data exchange**: APIs can be used to exchange data between different systems or applications.\n2. **Real-time updates**: APIs can be used to push real-time updates to clients or other systems.\n3. **Authentication**: APIs can be used to authenticate and authorize users or systems.\n4. **Microservices**: APIs can be used to enable communication between microservices within a larger application or system.\n\nI hope this helps you understand APIs better! Do you have any specific questions or use cases you'd like to discuss?"}
